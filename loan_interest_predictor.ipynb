# %%
import pandas as pd
import numpy as np
from openpyxl.styles.builtins import output
from scipy.stats import zscore

# %%
def load_data(file_path):
    """
    Load data from a CSV file.
    
    Args:
        file_path (str): Path to the CSV file.

    Returns:
        pd.DataFrame: Loaded data as a pandas DataFrame.
    """
    return pd.read_csv(file_path)

def convert_numeric_columns(df, columns):
    """
    Convert specified columns to numeric values by removing special characters.

    Args:
        df (pd.DataFrame): Dataset containing the columns to convert.
        columns (list): List of column names to convert.

    Returns:
        pd.DataFrame: Dataset with numeric columns converted.
    """
    for column in columns:
        df[column] = df[column].replace({r'\$': '', r',': ''}, regex=True).astype(float)
    return df

def filter_data(df, product_type, loan_amount, loan_term, credit_score, income):
    """
    Filter the dataset based on user input criteria.

    Args:
        df (pd.DataFrame): Dataset to filter.
        product_type (str): Desired product type (e.g., "Personal - Secured").
        loan_amount (int): Desired loan amount.
        loan_term (int): Desired loan term in months.
        credit_score (int): User's credit score.
        income (int): User's income.

    Returns:
        pd.DataFrame: Filtered dataset matching the criteria.
    """
    filtered_df = df[
        (df['Product_Type'].str.contains(product_type, case=False, na=False)) &
        (df['MinAmount'] <= loan_amount) &
        (df['MaxAmount'] >= loan_amount) &
        (df['MinTerm'] <= loan_term) &
        (df['MaxTerm'] >= loan_term) &
        (df['MinCreditScore'] <= credit_score) &
        (df['MinIncome'] <= income)
    ]
    return filtered_df

def get_best_options(filtered_df, top_n=3):
    """
    Get the top N best loan options sorted by minimum interest rate.

    Args:
        filtered_df (pd.DataFrame): Filtered dataset.
        top_n (int): Number of top options to return.

    Returns:
        pd.DataFrame: Top N loan options.
    """
    return filtered_df.sort_values(by='MinInterestRate').head(top_n)

def main(user_input):
    """
    Main function to process user input and return the best loan options as a numpy array.

    Args:
        user_input (list): List containing user criteria in the following order:
                          [product_type, loan_amount, loan_term, credit_score, income]

    Returns:
        np.ndarray: The best loan options as a numpy array.
    """
    # Load data
    file_path = '/Users/aliozsayin/Desktop/Axio_Prediction_Model_1-Demo/Book1.csv'
    data = load_data(file_path)

    # Convert necessary columns to numeric
    numeric_columns = ['MinIncome', 'MinAmount', 'MaxAmount', 'MinInterestRate', 'MaxInterestRate']
    data = convert_numeric_columns(data, numeric_columns)

    # Unpack user input
    product_type, loan_amount, loan_term, credit_score, income = user_input

    # Filter data
    filtered_data = filter_data(data, product_type, loan_amount, loan_term, credit_score, income)

    if filtered_data.empty:
        print("No options available based on your criteria.")
        return np.array([])  # Return an empty array if no options are available
    else:
        # Get best options
        best_options = get_best_options(filtered_data)
        return best_options.to_numpy()  # Return the best options as a numpy array

# %%
user_input = ["Personal - Secured", 10000, 36, 700, 50000] #Will get 
nplist = main(user_input)
nplist
# Out:
# array([['NF_PLS', 'NowFinance', 'Personal - Secured', 420, 35000.0, 6.75,
#         26.95, 24, 84, 5000.0, 100000.0, '$990 ', '$0 ', '$0 ', '$0 '],
#        ['Plenti_PLS', 'Plenti', 'Personal - Secured', 525, 35000.0, 9.49,
#         24.99, 24, 84, 5000.0, 150000.0, '$990 ', '$499 ', '$9 ', '$0 '],
#        ['Money3_PLS', 'Money3', 'Personal - Secured', 200, 20000.0,
#         12.95, 27.99, 24, 36, 5000.0, 50000.0, '$990 ', '$330 ', '$0 ',
#         '$0 ']], dtype=object)

# %% [markdown]
# # Working on the actual model

# %% [markdown]
# # Imports

# %%
import torch.nn as nn
import torch
import torch.nn.functional as F
from torch.utils.data import TensorDataset, DataLoader

import numpy as np
from statistics import mean

import pandas
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# Load the dataset
data = pd.read_csv('synthetic_data.csv')
label = data['interest_rate']  # Extract target variable

# Drop the target column from the dataset
data = data.drop('interest_rate', axis=1)

# Convert data and labels to numpy arrays
label = np.array(label)
data = np.array(data)

# %%
# Normalize the data and labels using z-score normalization
data = zscore(data)
label = zscore(label)

# Convert numpy arrays to PyTorch tensors
label = torch.tensor(label)
data = torch.tensor(data)

# Ensure tensors are of float type for compatibility with PyTorch models
data = data.float()
label = label.float()

# %%
train_d , test_d, train_l, test_l = train_test_split(data, label, test_size=0.05,shuffle=True)
train_l = train_l.unsqueeze(dim=1)
test_l = test_l.unsqueeze(dim=1)

train_set = TensorDataset(train_d,train_l)
test_set = TensorDataset(test_d,test_l)

train_split = DataLoader(train_set, batch_size=8, shuffle=True)

# %% [markdown]
# # ModelMaker

# %%
class ModelMaker(nn.Module):
    def __init__(self):
        super().__init__()
        self.input = nn.Linear(13, 32)
        self.hidden = nn.Linear(32, 64)
        self.output = nn.Linear(64, 1)
        self.dropout = nn.Dropout(p=0.0)  # Regularization with dropout

    def forward(self, x):
        x = F.relu(self.input(x))
        x = self.dropout(x)  # Apply dropout after the first layer
        x = F.relu(self.hidden(x))
        x = self.dropout(x)  # Apply dropout after the second layer
        x = self.output(x)  # No activation for regression
        return x

# %% [markdown]
# ## Creating the model and setting parameters

# %%
test_model = ModelMaker() #The model we will use throughout
optimizer = torch.optim.SGD(test_model.parameters(), lr=0.01) #optimizer
lossfunc = nn.MSELoss()

# %% [markdown]
# # Trainer Function:

# %%
epoch = 700
lossarr = np.zeros(epoch)

def trainer():
    # Loop through the specified number of epochs
    for e in range(epoch):
        # Iterate over batches in the training set
        for x, y in train_set:
            yHat = test_model(x)  # Forward pass
            loss = lossfunc(yHat, y)  # Compute loss
            
            optimizer.zero_grad()  # Reset gradients
            loss.backward()  # Backpropagation
            optimizer.step()  # Update model parameters
        
        print(loss)  # Print loss after each epoch

# %%
trainer() #Training our model
# Out:
# tensor(1.6895, grad_fn=<MseLossBackward0>)
# tensor(1.3627, grad_fn=<MseLossBackward0>)
# tensor(1.1479, grad_fn=<MseLossBackward0>)
# tensor(1.0062, grad_fn=<MseLossBackward0>)
# tensor(0.9777, grad_fn=<MseLossBackward0>)
# tensor(0.9063, grad_fn=<MseLossBackward0>)
# tensor(0.9828, grad_fn=<MseLossBackward0>)
# tensor(0.8687, grad_fn=<MseLossBackward0>)
# tensor(1.0627, grad_fn=<MseLossBackward0>)
# tensor(0.9706, grad_fn=<MseLossBackward0>)
# tensor(1.0535, grad_fn=<MseLossBackward0>)
# tensor(1.1365, grad_fn=<MseLossBackward0>)
grad_fn=<MseLossBackward0>)
# tensor(0.0029, grad_fn=<MseLossBackward0>)
# tensor(0.0027, grad_fn=<MseLossBackward0>)
# tensor(0.0254, grad_fn=<MseLossBackward0>)
# tensor(0.0351, grad_fn=<MseLossBackward0>)
# tensor(0.0252, grad_fn=<MseLossBackward0>)
# tensor(0.0105, grad_fn=<MseLossBackward0>)
# tensor(0.0033, grad_fn=<MseLossBackward0>)
# tensor(0.0172, grad_fn=<MseLossBackward0>)
# tensor(0.0019, grad_fn=<MseLossBackward0>)
# tensor(0.0153, grad_fn=<MseLossBackward0>)
# tensor(0.0006, grad_fn=<MseLossBackward0>)
# tensor(0.0200, grad_fn=<MseLossBackward0>)
# tensor(0.0024, grad_fn=<MseLossBackward0>)
# tensor(0.0078, grad_fn=<MseLossBackward0>)
# tensor(0.0069, grad_fn=<MseLossBackward0>)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor(0.0046, grad_fn=<MseLossBackward0>)
# tensor(0.0240, grad_fn=<MseLossBackward0>)
# tensor(0.0108, grad_fn=<MseLossBackward0>)
# tensor(8.2846e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0014, grad_fn=<MseLossBackward0>)
# tensor(1.3136e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0010, grad_fn=<MseLossBackward0>)
# tensor(2.6991e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor(0.0015, grad_fn=<MseLossBackward0>)
# tensor(0.0006, grad_fn=<MseLossBackward0>)
# tensor(6.3475e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor(0.0060, grad_fn=<MseLossBackward0>)
# tensor(0.0040, grad_fn=<MseLossBackward0>)
# tensor(1.0879e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(0.0041, grad_fn=<MseLossBackward0>)
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor(0.0028, grad_fn=<MseLossBackward0>)
# tensor(0.0006, grad_fn=<MseLossBackward0>)
# tensor(0.0088, grad_fn=<MseLossBackward0>)
# tensor(4.3010e-06, grad_fn=<MseLossBackward0>)
# tensor(9.5118e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0111, grad_fn=<MseLossBackward0>)
# tensor(0.0017, grad_fn=<MseLossBackward0>)
# tensor(0.0337, grad_fn=<MseLossBackward0>)
# tensor(0.0012, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0172, grad_fn=<MseLossBackward0>)
# tensor(0.0178, grad_fn=<MseLossBackward0>)
# tensor(0.0154, grad_fn=<MseLossBackward0>)
# tensor(0.0085, grad_fn=<MseLossBackward0>)
# tensor(0.0037, grad_fn=<MseLossBackward0>)
# tensor(0.0006, grad_fn=<MseLossBackward0>)
# tensor(0.0011, grad_fn=<MseLossBackward0>)
# tensor(0.0021, grad_fn=<MseLossBackward0>)
# tensor(0.0117, grad_fn=<MseLossBackward0>)
# tensor(0.0111, grad_fn=<MseLossBackward0>)
# tensor(0.0198, grad_fn=<MseLossBackward0>)
# tensor(8.0795e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(0.0084, grad_fn=<MseLossBackward0>)
# tensor(9.4816e-05, grad_fn=<MseLossBackward0>)
# tensor(1.1432e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor(1.3295e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0021, grad_fn=<MseLossBackward0>)
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor(0.0009, grad_fn=<MseLossBackward0>)
# tensor(0.0104, grad_fn=<MseLossBackward0>)
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor(0.0037, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0052, grad_fn=<MseLossBackward0>)
# tensor(0.0010, grad_fn=<MseLossBackward0>)
# tensor(0.0071, grad_fn=<MseLossBackward0>)
# tensor(4.2590e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0032, grad_fn=<MseLossBackward0>)
# tensor(0.0035, grad_fn=<MseLossBackward0>)
# tensor(0.0055, grad_fn=<MseLossBackward0>)
# tensor(0.0015, grad_fn=<MseLossBackward0>)
# tensor(0.0082, grad_fn=<MseLossBackward0>)
# tensor(0.0026, grad_fn=<MseLossBackward0>)
# tensor(0.0171, grad_fn=<MseLossBackward0>)
# tensor(0.0028, grad_fn=<MseLossBackward0>)
# tensor(0.0025, grad_fn=<MseLossBackward0>)
# tensor(1.8424e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0015, grad_fn=<MseLossBackward0>)
# tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor(0.0110, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0058, grad_fn=<MseLossBackward0>)
# tensor(0.0053, grad_fn=<MseLossBackward0>)
# tensor(0.0130, grad_fn=<MseLossBackward0>)
# tensor(0.0031, grad_fn=<MseLossBackward0>)
# tensor(0.0136, grad_fn=<MseLossBackward0>)
# tensor(0.0074, grad_fn=<MseLossBackward0>)
# tensor(0.0125, grad_fn=<MseLossBackward0>)
# tensor(0.0039, grad_fn=<MseLossBackward0>)
# tensor(0.0067, grad_fn=<MseLossBackward0>)
# tensor(0.0038, grad_fn=<MseLossBackward0>)
# tensor(0.0054, grad_fn=<MseLossBackward0>)
# tensor(0.0057, grad_fn=<MseLossBackward0>)
# tensor(2.3209e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0014, grad_fn=<MseLossBackward0>)
# tensor(7.3483e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0034, grad_fn=<MseLossBackward0>)
# tensor(4.3391e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0019, grad_fn=<MseLossBackward0>)
# tensor(0.0013, grad_fn=<MseLossBackward0>)
# tensor(0.0029, grad_fn=<MseLossBackward0>)
# tensor(0.0016, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0035, grad_fn=<MseLossBackward0>)
# tensor(4.4449e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0031, grad_fn=<MseLossBackward0>)
# tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor(5.9895e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor(0.0014, grad_fn=<MseLossBackward0>)
# tensor(0.0023, grad_fn=<MseLossBackward0>)
# tensor(3.4056e-05, grad_fn=<MseLossBackward0>)
# tensor(6.4461e-06, grad_fn=<MseLossBackward0>)
# tensor(0.0017, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor(0.0009, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor(3.1097e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor(0.0034, grad_fn=<MseLossBackward0>)
# tensor(0.0031, grad_fn=<MseLossBackward0>)
# tensor(0.0043, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(1.1157e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(4.3551e-06, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0011, grad_fn=<MseLossBackward0>)
# tensor(0.0015, grad_fn=<MseLossBackward0>)
# tensor(0.0068, grad_fn=<MseLossBackward0>)
# tensor(0.0019, grad_fn=<MseLossBackward0>)
# tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(7.1912e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0020, grad_fn=<MseLossBackward0>)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor(0.0024, grad_fn=<MseLossBackward0>)
# tensor(0.0024, grad_fn=<MseLossBackward0>)
# tensor(0.0047, grad_fn=<MseLossBackward0>)
# tensor(0.0020, grad_fn=<MseLossBackward0>)
# tensor(0.0052, grad_fn=<MseLossBackward0>)
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor(1.1123e-06, grad_fn=<MseLossBackward0>)
# tensor(0.0019, grad_fn=<MseLossBackward0>)
# tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor(0.0052, grad_fn=<MseLossBackward0>)
# tensor(0.0022, grad_fn=<MseLossBackward0>)
# tensor(0.0075, grad_fn=<MseLossBackward0>)
# tensor(0.0082, grad_fn=<MseLossBackward0>)
# tensor(0.0085, grad_fn=<MseLossBackward0>)
# tensor(0.0028, grad_fn=<MseLossBackward0>)
# tensor(0.0010, grad_fn=<MseLossBackward0>)
# tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor(9.1531e-06, grad_fn=<MseLossBackward0>)
# tensor(0.0053, grad_fn=<MseLossBackward0>)
# tensor(0.0117, grad_fn=<MseLossBackward0>)
# tensor(0.0179, grad_fn=<MseLossBackward0>)
# tensor(0.0124, grad_fn=<MseLossBackward0>)
# tensor(0.0049, grad_fn=<MseLossBackward0>)
# tensor(0.0030, grad_fn=<MseLossBackward0>)
# tensor(0.0021, grad_fn=<MseLossBackward0>)
# tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor(8.6127e-07, grad_fn=<MseLossBackward0>)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor(0.0025, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0052, grad_fn=<MseLossBackward0>)
# tensor(0.0040, grad_fn=<MseLossBackward0>)
# tensor(0.0024, grad_fn=<MseLossBackward0>)
# tensor(4.0634e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(0.0012, grad_fn=<MseLossBackward0>)
# tensor(0.0011, grad_fn=<MseLossBackward0>)
# tensor(0.0030, grad_fn=<MseLossBackward0>)
# tensor(0.0048, grad_fn=<MseLossBackward0>)
# tensor(0.0130, grad_fn=<MseLossBackward0>)
# tensor(0.0062, grad_fn=<MseLossBackward0>)
# tensor(0.0066, grad_fn=<MseLossBackward0>)
# tensor(0.0119, grad_fn=<MseLossBackward0>)
# tensor(0.0125, grad_fn=<MseLossBackward0>)
# tensor(0.0017, grad_fn=<MseLossBackward0>)
# tensor(0.0046, grad_fn=<MseLossBackward0>)
# tensor(0.0060, grad_fn=<MseLossBackward0>)
# tensor(0.0107, grad_fn=<MseLossBackward0>)
# tensor(0.0063, grad_fn=<MseLossBackward0>)
# tensor(0.0080, grad_fn=<MseLossBackward0>)
# tensor(0.0070, grad_fn=<MseLossBackward0>)
# tensor(0.0040, grad_fn=<MseLossBackward0>)
# tensor(0.0025, grad_fn=<MseLossBackward0>)
# tensor(0.0011, grad_fn=<MseLossBackward0>)
# tensor(8.4629e-07, grad_fn=<MseLossBackward0>)
# tensor(9.3383e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0016, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0015, grad_fn=<MseLossBackward0>)
# tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor(0.0013, grad_fn=<MseLossBackward0>)
# tensor(0.0017, grad_fn=<MseLossBackward0>)
# tensor(0.0064, grad_fn=<MseLossBackward0>)
# tensor(0.0018, grad_fn=<MseLossBackward0>)
# tensor(0.0052, grad_fn=<MseLossBackward0>)
# tensor(0.0022, grad_fn=<MseLossBackward0>)
# tensor(0.0028, grad_fn=<MseLossBackward0>)
# tensor(0.0021, grad_fn=<MseLossBackward0>)
# tensor(3.3179e-08, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0024, grad_fn=<MseLossBackward0>)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor(0.0036, grad_fn=<MseLossBackward0>)
# tensor(0.0049, grad_fn=<MseLossBackward0>)
# tensor(0.0062, grad_fn=<MseLossBackward0>)
# tensor(0.0060, grad_fn=<MseLossBackward0>)
# tensor(0.0048, grad_fn=<MseLossBackward0>)
# tensor(0.0023, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0026, grad_fn=<MseLossBackward0>)
# tensor(2.5046e-05, grad_fn=<MseLossBackward0>)
# tensor(1.0646e-07, grad_fn=<MseLossBackward0>)
# tensor(0.0059, grad_fn=<MseLossBackward0>)
# tensor(0.0063, grad_fn=<MseLossBackward0>)
# tensor(0.0181, grad_fn=<MseLossBackward0>)
# tensor(0.0130, grad_fn=<MseLossBackward0>)
# tensor(0.0133, grad_fn=<MseLossBackward0>)
# tensor(0.0132, grad_fn=<MseLossBackward0>)
# tensor(0.0053, grad_fn=<MseLossBackward0>)
# tensor(0.0019, grad_fn=<MseLossBackward0>)
# tensor(0.0014, grad_fn=<MseLossBackward0>)
# tensor(0.0026, grad_fn=<MseLossBackward0>)
# tensor(0.0027, grad_fn=<MseLossBackward0>)
# tensor(0.0043, grad_fn=<MseLossBackward0>)
# tensor(0.0028, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0085, grad_fn=<MseLossBackward0>)
# tensor(0.0065, grad_fn=<MseLossBackward0>)
# tensor(0.0073, grad_fn=<MseLossBackward0>)
# tensor(0.0019, grad_fn=<MseLossBackward0>)
# tensor(0.0027, grad_fn=<MseLossBackward0>)
# tensor(0.0016, grad_fn=<MseLossBackward0>)
# tensor(0.0053, grad_fn=<MseLossBackward0>)
# tensor(0.0022, grad_fn=<MseLossBackward0>)
# tensor(0.0026, grad_fn=<MseLossBackward0>)
# tensor(0.0021, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0011, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(0.0011, grad_fn=<MseLossBackward0>)
# tensor(0.0023, grad_fn=<MseLossBackward0>)
# tensor(0.0051, grad_fn=<MseLossBackward0>)
# tensor(0.0054, grad_fn=<MseLossBackward0>)
# tensor(0.0024, grad_fn=<MseLossBackward0>)
# tensor(0.0012, grad_fn=<MseLossBackward0>)
# tensor(4.2835e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(0.0010, grad_fn=<MseLossBackward0>)
# tensor(0.0032, grad_fn=<MseLossBackward0>)
# tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(9.8849e-06, grad_fn=<MseLossBackward0>)
# tensor(8.8333e-05, grad_fn=<MseLossBackward0>)
# tensor(7.6067e-06, grad_fn=<MseLossBackward0>)
# tensor(1.2288e-06, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0007, grad_fn=<MseLossBackward0>)
# tensor(0.0006, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(7.9122e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor(5.9165e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(1.9923e-05, grad_fn=<MseLossBackward0>)
# tensor(3.8299e-05, grad_fn=<MseLossBackward0>)
# tensor(2.3392e-05, grad_fn=<MseLossBackward0>)
# tensor(7.4836e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(2.7622e-05, grad_fn=<MseLossBackward0>)
# tensor(1.9986e-06, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(2.3860e-05, grad_fn=<MseLossBackward0>)
# tensor(8.0665e-06, grad_fn=<MseLossBackward0>)
# tensor(1.8592e-07, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(3.0183e-05, grad_fn=<MseLossBackward0>)
# tensor(1.8350e-05, grad_fn=<MseLossBackward0>)
# tensor(5.9156e-05, grad_fn=<MseLossBackward0>)
# tensor(7.8303e-07, grad_fn=<MseLossBackward0>)
# tensor(8.9771e-07, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(4.4441e-05, grad_fn=<MseLossBackward0>)
# tensor(3.4256e-06, grad_fn=<MseLossBackward0>)
# tensor(9.4758e-05, grad_fn=<MseLossBackward0>)
# tensor(3.5761e-05, grad_fn=<MseLossBackward0>)
# tensor(5.4548e-06, grad_fn=<MseLossBackward0>)
# tensor(5.7747e-05, grad_fn=<MseLossBackward0>)
# tensor(6.4900e-05, grad_fn=<MseLossBackward0>)
# tensor(3.9750e-05, grad_fn=<MseLossBackward0>)
# tensor(1.1942e-05, grad_fn=<MseLossBackward0>)
# tensor(2.6234e-05, grad_fn=<MseLossBackward0>)
# tensor(4.7330e-05, grad_fn=<MseLossBackward0>)
# tensor(9.4137e-07, grad_fn=<MseLossBackward0>)
# tensor(3.8867e-06, grad_fn=<MseLossBackward0>)
# tensor(9.7661e-06, grad_fn=<MseLossBackward0>)
# tensor(2.4027e-05, grad_fn=<MseLossBackward0>)
# tensor(2.8773e-05, grad_fn=<MseLossBackward0>)
# tensor(4.1194e-05, grad_fn=<MseLossBackward0>)
# tensor(2.2347e-06, grad_fn=<MseLossBackward0>)
# tensor(1.3647e-05, grad_fn=<MseLossBackward0>)
# tensor(3.1410e-05, grad_fn=<MseLossBackward0>)
# tensor(1.4313e-06, grad_fn=<MseLossBackward0>)
# tensor(1.4688e-05, grad_fn=<MseLossBackward0>)
# tensor(4.9790e-05, grad_fn=<MseLossBackward0>)
# tensor(1.9251e-06, grad_fn=<MseLossBackward0>)
# tensor(1.5279e-07, grad_fn=<MseLossBackward0>)
# tensor(1.1626e-05, grad_fn=<MseLossBackward0>)
# tensor(1.8339e-08, grad_fn=<MseLossBackward0>)
# tensor(9.4670e-07, grad_fn=<MseLossBackward0>)
# tensor(2.4775e-05, grad_fn=<MseLossBackward0>)
# tensor(7.4192e-06, grad_fn=<MseLossBackward0>)
# tensor(1.0569e-06, grad_fn=<MseLossBackward0>)
# tensor(6.3598e-05, grad_fn=<MseLossBackward0>)
# tensor(5.7759e-05, grad_fn=<MseLossBackward0>)
# tensor(2.8791e-05, grad_fn=<MseLossBackward0>)
# tensor(9.4073e-06, grad_fn=<MseLossBackward0>)
# tensor(1.4378e-05, grad_fn=<MseLossBackward0>)
# tensor(4.8773e-06, grad_fn=<MseLossBackward0>)
# tensor(8.1786e-06, grad_fn=<MseLossBackward0>)
# tensor(5.9849e-06, grad_fn=<MseLossBackward0>)
# tensor(6.0299e-06, grad_fn=<MseLossBackward0>)
# tensor(2.7585e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5458e-05, grad_fn=<MseLossBackward0>)
# tensor(8.6142e-05, grad_fn=<MseLossBackward0>)
# tensor(6.7201e-06, grad_fn=<MseLossBackward0>)
# tensor(1.2688e-06, grad_fn=<MseLossBackward0>)
# tensor(1.2417e-05, grad_fn=<MseLossBackward0>)
# tensor(7.2853e-09, grad_fn=<MseLossBackward0>)
# tensor(5.1799e-06, grad_fn=<MseLossBackward0>)
# tensor(5.1689e-05, grad_fn=<MseLossBackward0>)
# tensor(1.4495e-05, grad_fn=<MseLossBackward0>)
# tensor(1.9132e-05, grad_fn=<MseLossBackward0>)
# tensor(1.4074e-07, grad_fn=<MseLossBackward0>)
# tensor(1.3676e-06, grad_fn=<MseLossBackward0>)
# tensor(1.6173e-06, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(5.0143e-05, grad_fn=<MseLossBackward0>)
# tensor(2.4004e-05, grad_fn=<MseLossBackward0>)
# tensor(2.6406e-05, grad_fn=<MseLossBackward0>)
# tensor(4.3007e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(8.8302e-05, grad_fn=<MseLossBackward0>)
# tensor(7.7604e-05, grad_fn=<MseLossBackward0>)
# tensor(3.1369e-05, grad_fn=<MseLossBackward0>)
# tensor(4.6349e-05, grad_fn=<MseLossBackward0>)
# tensor(6.8939e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor(5.2115e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(1.9418e-05, grad_fn=<MseLossBackward0>)
# tensor(9.9257e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(5.4377e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(7.1855e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(2.9459e-07, grad_fn=<MseLossBackward0>)
# tensor(0.0010, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(0.0011, grad_fn=<MseLossBackward0>)
# tensor(0.0008, grad_fn=<MseLossBackward0>)
# tensor(0.0013, grad_fn=<MseLossBackward0>)
# tensor(0.0009, grad_fn=<MseLossBackward0>)
# tensor(0.0013, grad_fn=<MseLossBackward0>)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# tensor(3.5265e-05, grad_fn=<MseLossBackward0>)
# tensor(7.7388e-05, grad_fn=<MseLossBackward0>)
# tensor(4.5737e-08, grad_fn=<MseLossBackward0>)
# tensor(2.1491e-05, grad_fn=<MseLossBackward0>)
# tensor(4.8201e-06, grad_fn=<MseLossBackward0>)
# tensor(4.9772e-05, grad_fn=<MseLossBackward0>)
# tensor(5.0602e-06, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(2.1735e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(5.0160e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# tensor(4.2081e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(1.0299e-05, grad_fn=<MseLossBackward0>)
# tensor(9.3512e-05, grad_fn=<MseLossBackward0>)
# tensor(1.5336e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5079e-05, grad_fn=<MseLossBackward0>)
# tensor(7.6442e-06, grad_fn=<MseLossBackward0>)
# tensor(2.3786e-05, grad_fn=<MseLossBackward0>)
# tensor(6.1968e-06, grad_fn=<MseLossBackward0>)
# tensor(1.0942e-05, grad_fn=<MseLossBackward0>)
# tensor(6.0122e-05, grad_fn=<MseLossBackward0>)
# tensor(4.3620e-08, grad_fn=<MseLossBackward0>)
# tensor(5.8191e-05, grad_fn=<MseLossBackward0>)
# tensor(1.8833e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# tensor(1.4336e-05, grad_fn=<MseLossBackward0>)
# tensor(6.8996e-05, grad_fn=<MseLossBackward0>)
# tensor(1.1017e-06, grad_fn=<MseLossBackward0>)
# tensor(3.1654e-05, grad_fn=<MseLossBackward0>)
# tensor(7.8319e-06, grad_fn=<MseLossBackward0>)
# tensor(2.2369e-05, grad_fn=<MseLossBackward0>)
# tensor(6.6979e-06, grad_fn=<MseLossBackward0>)
# tensor(2.0611e-05, grad_fn=<MseLossBackward0>)
# tensor(3.3249e-07, grad_fn=<MseLossBackward0>)
# tensor(5.0927e-05, grad_fn=<MseLossBackward0>)
# tensor(9.9818e-06, grad_fn=<MseLossBackward0>)
# tensor(3.6657e-05, grad_fn=<MseLossBackward0>)
# tensor(5.9121e-09, grad_fn=<MseLossBackward0>)
# tensor(9.7170e-06, grad_fn=<MseLossBackward0>)
# tensor(5.8717e-06, grad_fn=<MseLossBackward0>)
# tensor(2.7299e-06, grad_fn=<MseLossBackward0>)
# tensor(1.4143e-06, grad_fn=<MseLossBackward0>)
# tensor(4.8060e-06, grad_fn=<MseLossBackward0>)
# tensor(5.4231e-06, grad_fn=<MseLossBackward0>)
# tensor(3.2308e-05, grad_fn=<MseLossBackward0>)
# tensor(1.0183e-05, grad_fn=<MseLossBackward0>)
# tensor(4.6163e-05, grad_fn=<MseLossBackward0>)
# tensor(1.7210e-05, grad_fn=<MseLossBackward0>)
# tensor(3.7896e-05, grad_fn=<MseLossBackward0>)
# tensor(3.6339e-06, grad_fn=<MseLossBackward0>)
# tensor(7.2423e-06, grad_fn=<MseLossBackward0>)
# tensor(3.4001e-06, grad_fn=<MseLossBackward0>)
# tensor(4.0703e-06, grad_fn=<MseLossBackward0>)
# tensor(3.6786e-05, grad_fn=<MseLossBackward0>)
# tensor(2.6820e-05, grad_fn=<MseLossBackward0>)
# tensor(3.6571e-05, grad_fn=<MseLossBackward0>)
# tensor(3.1022e-06, grad_fn=<MseLossBackward0>)
# tensor(2.4628e-07, grad_fn=<MseLossBackward0>)
# tensor(3.2880e-05, grad_fn=<MseLossBackward0>)
# tensor(6.0439e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(4.0838e-05, grad_fn=<MseLossBackward0>)
# tensor(2.3586e-05, grad_fn=<MseLossBackward0>)
# tensor(1.0328e-05, grad_fn=<MseLossBackward0>)
# tensor(5.5373e-05, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# tensor(2.5719e-05, grad_fn=<MseLossBackward0>)
# tensor(5.9855e-06, grad_fn=<MseLossBackward0>)
# tensor(3.1547e-05, grad_fn=<MseLossBackward0>)
# tensor(3.4791e-05, grad_fn=<MseLossBackward0>)
# tensor(8.0073e-05, grad_fn=<MseLossBackward0>)
# tensor(3.6069e-05, grad_fn=<MseLossBackward0>)
# tensor(4.8663e-05, grad_fn=<MseLossBackward0>)
# tensor(3.3317e-07, grad_fn=<MseLossBackward0>)
# tensor(2.5500e-07, grad_fn=<MseLossBackward0>)
# tensor(1.9977e-05, grad_fn=<MseLossBackward0>)
# tensor(1.6014e-05, grad_fn=<MseLossBackward0>)
# tensor(3.9501e-05, grad_fn=<MseLossBackward0>)
# tensor(1.6714e-06, grad_fn=<MseLossBackward0>)

# %% [markdown]
# # Saving our model:

# %%
def save_model(test_model, path="Axio_Model.pth"):
    # Save the entire model, including architecture and weights
    torch.save(test_model, path)
    print(f"Model saved to {path}")

save_model(test_model, 'Axio_Model.pth')
# Out:
# Model saved to Axio_Model.pth

# %% [markdown]
# # Test Accuracy:

# %%
correct = 0
total = 0
for x, y in train_set:
    yHat = test_model(x)
    loss = lossfunc(yHat, y)
    
    tolerance = 0.1
    correct += ((yHat - y).abs() <= tolerance).sum().item()
    total += y.size(0)

accuracy = (correct / total) * 100 if total > 0 else 0
print(f"Overall Accuracy: {accuracy:.2f}%")

correct = 0
total = 0

for x, y in test_set:
    yHat = test_model(x)
    loss = lossfunc(yHat, y)

    tolerance = 0.3
    correct += ((yHat - y).abs() <= tolerance).sum().item()
    total += y.size(0)

accuracy = (correct / total) * 100 if total > 0 else 0
print(f"Overall Accuracy: {accuracy:.2f}%")
# Out:
# Overall Accuracy: 99.68%
# Overall Accuracy: 16.00%

# %% [markdown]
# # <span style="color:red;">CODE FOR THE SYNTHETIC DATA</span>

# %%
import pandas as pd
import random

# Defining patterns with some relationships
patterns = {
    "ProductType": [0, 1],
    "term": [12, 24, 36, 48, 60, 72, 84],
    "amount": (5000, 15000),
    "Secured": [0, 1],
    "coApplicant": [0, 1],
    "CreditScore": (300, 850),  # More realistic credit score range
    "Residency": [0, 1, 2],
    "CitizenOrNot": [0, 1],
    "visaSubclass": (0, 100),
    "visaTimeLeftInMonths": (0, 36),
    "age": (18, 70),
    "LoanPurpose": [0, 1, 2, 3, 4, 5, 6],
    "RepaymentFrequency": [0, 1, 2],
    "interest_rate": (15.0, 25.0),
}

# Generating 1000 rows with relationships
rows = []
for _ in range(1000):
    credit_score = random.randint(*patterns["CreditScore"])
    term = random.choice(patterns["term"])
    amount = random.randint(*patterns["amount"])

    # Relationships: lower credit score -> higher interest rate
    interest_rate = round(random.uniform(15.0, 25.0) - (credit_score / 1000 * 5), 2)

    # Longer terms for higher loan amounts
    if amount > 12000:
        term = random.choice([48, 60, 72, 84])

    # Younger applicants more likely to have co-applicants
    age = random.randint(*patterns["age"])
    co_applicant = 1 if age < 30 else random.choice(patterns["coApplicant"])

    row = {
        "ProductType": random.choice(patterns["ProductType"]),
        "term": term,
        "amount": amount,
        "Secured": random.choice(patterns["Secured"]),
        "coApplicant": co_applicant,
        "CreditScore": credit_score,
        "Residency": random.choice(patterns["Residency"]),
        "CitizenOrNot": random.choice(patterns["CitizenOrNot"]),
        "visaSubclass": random.randint(*patterns["visaSubclass"]),
        "visaTimeLeftInMonths": random.randint(*patterns["visaTimeLeftInMonths"]),
        "age": age,
        "LoanPurpose": random.choice(patterns["LoanPurpose"]),
        "RepaymentFrequency": random.choice(patterns["RepaymentFrequency"]),
        "interest_rate": interest_rate,
    }
    rows.append(row)

# Create a DataFrame
synthetic_data = pd.DataFrame(rows)

# Display the first few rows of the DataFrame
synthetic_data.head()
# Out:
#    ProductType  term  amount  Secured  coApplicant  CreditScore  Residency  \
# 0            1    12    6917        1            1          424          1
# 1            1    36    5331        0            1          387          1
# 2            1    60    9778        0            1          631          1
# 3            0    84   14900        0            0          385          0
# 4            1    60   14688        1            0          700          1
#
#    CitizenOrNot  visaSubclass  visaTimeLeftInMonths  age  LoanPurpose  \
# 0             1            92                    29   49            6
# 1             1            31                     5   25            1
# 2             0            43                    20   41            3
# 3             0            14                    28   64            3
# 4             1            56                    26   53            1
#
#    RepaymentFrequency  interest_rate
# 0                   0          14.68
# 1                   1          14.77
# 2                   0          20.12
# 3                   2          18.80
# 4                   1          20.57
